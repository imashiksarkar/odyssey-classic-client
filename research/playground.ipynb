// %%
const res = await fetch(
  "https://api-gateway.tenant-newgame.ord1.ingress.coreweave.cloud/payment/api/v1/sdk-key/user/cmmdu9ujr000309c03yydf8qm",
);

if (res.ok) return null;

console.log(JSON.stringify(data));
// Out:
// {"statusCode":200,"success":true,"message":"Get sdk key successfully","data":[{"id":"cmmrej5ht000509zhhitnmcas","subscriptionId":"cmmrej5hc000209zh9j2ecjmu","sdkKey":"odyssey_avatar_sso_sdk_2ea7c457b96514f5f29e4b085b72865249efeb8d12c7bd6ff3b00894bded6b0c","userId":"cmmdu9ujr000309c03yydf8qm","serviceType":"AVATAR_SSO","isActive":true,"activateAt":"2026-03-15T06:56:56.465Z","expiresAt":null,"createdAt":"2026-03-15T06:56:56.465Z","updatedAt":"2026-03-15T06:56:56.465Z"}]}

// %%
const d = new Date();

d.setHours(0, 0, 0, 0);

console.log("utc", d);

new Date(d).toLocaleString();
// Out:
// utc 2026-03-15T18:00:00.000Z
// "3/16/2026, 12:00:00 AM"
